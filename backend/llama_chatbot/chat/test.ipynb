# %%
import ollama

stream = ollama.chat(
    model='llama3.1',
    messages=[{'role': 'user', 'content': 'Why is the sky blue?'}],
    stream=True,
)

for chunk in stream:
  print(chunk['message']['content'], end='', flush=True)
# Out:
# The sky appears blue to us during
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       1 import ollama
#       3 stream = ollama.chat(
#       4     model='llama3.1',
#       5     messages=[{'role': 'user', 'content': 'Why is the sky blue?'}],
#       6     stream=True,
#       7 )
# ----> 9 for chunk in stream:
#      10   print(chunk['message']['content'], end='', flush=True)
#
# File ~/opt/anaconda3/envs/chatbot_app/lib/python3.12/site-packages/ollama/_client.py:86, in Client._stream(self, method, url, **kwargs)
#      83   e.response.read()
#      84   raise ResponseError(e.response.text, e.response.status_code) from None
# ---> 86 for line in r.iter_lines():
#      87   partial = json.loads(line)
#      88   if e := partial.get('error'):
#
# ...
